# %% [markdown]
# # Demo
#
# Injection of first order logic rules into a neural network for iris classification task.
#
# Download antlr4 jar and create parser for Datalog.g4 grammar.

# %%
! wget https://www.antlr.org/download/antlr-4.9.2-complete.jar
! export CLASSPATH="./antlr-4.9.2-complete.jar:$CLASSPATH"
! java -jar ./antlr-4.9.2-complete.jar -Dlanguage=Python3 resources/Datalog.g4 -visitor -o resources/dist
! rm ./antlr-4.9.2-complete.jar
# Out:
# --2022-03-08 15:43:19--  https://www.antlr.org/download/antlr-4.9.2-complete.jar
# Resolving www.antlr.org (www.antlr.org)... 185.199.110.153, 185.199.109.153, 185.199.108.153, ...
# Connecting to www.antlr.org (www.antlr.org)|185.199.110.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2100564 (2.0M) [application/java-archive]
# Saving to: ‘antlr-4.9.2-complete.jar’
#
# antlr-4.9.2-complet 100%[===================>]   2.00M  --.-KB/s    in 0.1s
#
# 2022-03-08 15:43:19 (13.7 MB/s) - ‘antlr-4.9.2-complete.jar’ saved [2100564/2100564]

# %% [markdown]
# Some import.

# %%
from antlr4 import InputStream, CommonTokenStream
from tensorflow.keras import Input, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.python.framework.random_seed import set_random_seed
from psyki.logic.datalog.grammar.adapters import Antlr4
from resources.dist.resources.DatalogLexer import DatalogLexer
from resources.dist.resources.DatalogParser import DatalogParser
from psyki.ski.injectors import NetworkComposer
from test.utils import get_mlp
from test.resources.rules import get_rules
from test.utils import get_processed_dataset, get_class_accuracy, get_f1

# %% [markdown]
# Loading iris dataset and separation into train and test set.

# %%
train_x, train_y, test_x, test_y = get_processed_dataset('poker')
train_x
# Out:
# array([[ 1., 10.,  1., ..., 12.,  1.,  1.],
#        [ 2., 11.,  2., ..., 12.,  2.,  1.],
#        [ 3., 12.,  3., ..., 10.,  3.,  1.],
#        ...,
#        [ 2.,  1.,  2., ...,  1.,  4., 13.],
#        [ 2., 12.,  4., ..., 12.,  4.,  9.],
#        [ 1.,  7.,  3., ...,  8.,  3.,  7.]])

# %% [markdown]
# Import Datalog rules.

# %%
feature_mapping = {
        'S1': 0,
        'R1': 1,
        'S2': 2,
        'R2': 3,
        'S3': 4,
        'R3': 5,
        'S4': 6,
        'R4': 7,
        'S5': 8,
        'R5': 9
    }

poker_rules = get_rules('poker')
formulae = [Antlr4().get_formula(DatalogParser(CommonTokenStream(DatalogLexer(InputStream(rule)))).formula()) for rule in poker_rules]

# %% [markdown]
# Injection of fuzzy logic function derived from Datalog rules into a neural network.

# %%
set_random_seed(0)
input_features = Input((10,), name='Input')
network = get_mlp(input_layer=input_features, output=10, layers=3, neurons=64, activation_function='relu', last_activation_function='softmax')
model = Model(input_features, network)
injector = NetworkComposer(model, feature_mapping)
injector.inject(formulae)
injector.predictor.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
injector.predictor.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 10)]         0
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# concatenate_80 (Concatenate)    (None, 2)            0           lambda_20[0][0]
#                                                                  lambda_21[0][0]
# __________________________________________________________________________________________________
# concatenate_88 (Concatenate)    (None, 2)            0           lambda_22[0][0]
#                                                                  lambda_23[0][0]
# __________________________________________________________________________________________________
# concatenate_104 (Concatenate)   (None, 2)            0           lambda_24[0][0]
#                                                                  lambda_25[0][0]
# __________________________________________________________________________________________________
# concatenate_112 (Concatenate)   (None, 2)            0           lambda_26[0][0]
#                                                                  lambda_27[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# dense_83 (Dense)                (None, 1)            3           concatenate_80[0][0]
# __________________________________________________________________________________________________
# dense_91 (Dense)                (None, 1)            3           concatenate_88[0][0]
# __________________________________________________________________________________________________
# dense_107 (Dense)               (None, 1)            3           concatenate_104[0][0]
# __________________________________________________________________________________________________
# dense_115 (Dense)               (None, 1)            3           concatenate_112[0][0]
# __________________________________________________________________________________________________
# concatenate_128 (Concatenate)   (None, 2)            0           lambda_28[0][0]
#                                                                  lambda_29[0][0]
# __________________________________________________________________________________________________
# concatenate_136 (Concatenate)   (None, 2)            0           lambda_30[0][0]
#                                                                  lambda_31[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# minimum_24 (Minimum)            (None, 1)            0           dense_83[0][0]
#                                                                  dense_91[0][0]
# __________________________________________________________________________________________________
# minimum_30 (Minimum)            (None, 1)            0           dense_107[0][0]
#                                                                  dense_115[0][0]
# __________________________________________________________________________________________________
# dense_131 (Dense)               (None, 1)            3           concatenate_128[0][0]
# __________________________________________________________________________________________________
# dense_139 (Dense)               (None, 1)            3           concatenate_136[0][0]
# __________________________________________________________________________________________________
# concatenate_152 (Concatenate)   (None, 2)            0           lambda_32[0][0]
#                                                                  lambda_33[0][0]
# __________________________________________________________________________________________________
# concatenate_160 (Concatenate)   (None, 2)            0           lambda_34[0][0]
#                                                                  lambda_35[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2)            0           lambda[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 2)            0           lambda_2[0][0]
#                                                                  lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_9 (TFOpLambda)  (None, 1)            0           minimum_24[0][0]
#                                                                  minimum_30[0][0]
# __________________________________________________________________________________________________
# minimum_36 (Minimum)            (None, 1)            0           dense_131[0][0]
#                                                                  dense_139[0][0]
# __________________________________________________________________________________________________
# dense_155 (Dense)               (None, 1)            3           concatenate_152[0][0]
# __________________________________________________________________________________________________
# dense_163 (Dense)               (None, 1)            3           concatenate_160[0][0]
# __________________________________________________________________________________________________
# concatenate_176 (Concatenate)   (None, 2)            0           lambda_36[0][0]
#                                                                  lambda_37[0][0]
# __________________________________________________________________________________________________
# concatenate_184 (Concatenate)   (None, 2)            0           lambda_38[0][0]
#                                                                  lambda_39[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            3           concatenate[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1)            3           concatenate_8[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 2)            0           lambda_4[0][0]
#                                                                  lambda_5[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_10 (TFOpLambda) (None, 1)            0           tf.math.minimum_9[0][0]
#                                                                  minimum_36[0][0]
# __________________________________________________________________________________________________
# minimum_42 (Minimum)            (None, 1)            0           dense_155[0][0]
#                                                                  dense_163[0][0]
# __________________________________________________________________________________________________
# dense_179 (Dense)               (None, 1)            3           concatenate_176[0][0]
# __________________________________________________________________________________________________
# dense_187 (Dense)               (None, 1)            3           concatenate_184[0][0]
# __________________________________________________________________________________________________
# concatenate_200 (Concatenate)   (None, 2)            0           lambda_40[0][0]
#                                                                  lambda_41[0][0]
# __________________________________________________________________________________________________
# concatenate_208 (Concatenate)   (None, 2)            0           lambda_42[0][0]
#                                                                  lambda_43[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_80 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_81 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_82 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_83 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_84 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_85 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_86 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_87 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_125 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_126 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_130 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_131 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum (TFOpLambda)    (None, 1)            0           dense_3[0][0]
#                                                                  dense_11[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 1)            3           concatenate_16[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 2)            0           lambda_6[0][0]
#                                                                  lambda_7[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_11 (TFOpLambda) (None, 1)            0           tf.math.minimum_10[0][0]
#                                                                  minimum_42[0][0]
# __________________________________________________________________________________________________
# minimum_48 (Minimum)            (None, 1)            0           dense_179[0][0]
#                                                                  dense_187[0][0]
# __________________________________________________________________________________________________
# dense_203 (Dense)               (None, 1)            3           concatenate_200[0][0]
# __________________________________________________________________________________________________
# dense_211 (Dense)               (None, 1)            3           concatenate_208[0][0]
# __________________________________________________________________________________________________
# concatenate_224 (Concatenate)   (None, 2)            0           lambda_44[0][0]
#                                                                  lambda_45[0][0]
# __________________________________________________________________________________________________
# concatenate_232 (Concatenate)   (None, 2)            0           lambda_46[0][0]
#                                                                  lambda_47[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# concatenate_440 (Concatenate)   (None, 2)            0           lambda_80[0][0]
#                                                                  lambda_81[0][0]
# __________________________________________________________________________________________________
# concatenate_448 (Concatenate)   (None, 2)            0           lambda_82[0][0]
#                                                                  lambda_83[0][0]
# __________________________________________________________________________________________________
# concatenate_464 (Concatenate)   (None, 2)            0           lambda_84[0][0]
#                                                                  lambda_85[0][0]
# __________________________________________________________________________________________________
# concatenate_472 (Concatenate)   (None, 2)            0           lambda_86[0][0]
#                                                                  lambda_87[0][0]
# __________________________________________________________________________________________________
# lambda_88 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_89 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_90 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_91 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# concatenate_719 (Concatenate)   (None, 2)            0           lambda_125[0][0]
#                                                                  lambda_126[0][0]
# __________________________________________________________________________________________________
# lambda_120 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_121 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# concatenate_791 (Concatenate)   (None, 2)            0           lambda_130[0][0]
#                                                                  lambda_131[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_1 (TFOpLambda)  (None, 1)            0           tf.math.minimum[0][0]
#                                                                  dense_19[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 1)            3           concatenate_24[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 2)            0           lambda_8[0][0]
#                                                                  lambda_9[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_12 (TFOpLambda) (None, 1)            0           tf.math.minimum_11[0][0]
#                                                                  minimum_48[0][0]
# __________________________________________________________________________________________________
# minimum_54 (Minimum)            (None, 1)            0           dense_203[0][0]
#                                                                  dense_211[0][0]
# __________________________________________________________________________________________________
# dense_227 (Dense)               (None, 1)            3           concatenate_224[0][0]
# __________________________________________________________________________________________________
# dense_235 (Dense)               (None, 1)            3           concatenate_232[0][0]
# __________________________________________________________________________________________________
# concatenate_248 (Concatenate)   (None, 2)            0           lambda_48[0][0]
#                                                                  lambda_49[0][0]
# __________________________________________________________________________________________________
# concatenate_256 (Concatenate)   (None, 2)            0           lambda_50[0][0]
#                                                                  lambda_51[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_53 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_54 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_55 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# dense_443 (Dense)               (None, 1)            3           concatenate_440[0][0]
# __________________________________________________________________________________________________
# dense_451 (Dense)               (None, 1)            3           concatenate_448[0][0]
# __________________________________________________________________________________________________
# dense_467 (Dense)               (None, 1)            3           concatenate_464[0][0]
# __________________________________________________________________________________________________
# dense_475 (Dense)               (None, 1)            3           concatenate_472[0][0]
# __________________________________________________________________________________________________
# concatenate_488 (Concatenate)   (None, 2)            0           lambda_88[0][0]
#                                                                  lambda_89[0][0]
# __________________________________________________________________________________________________
# concatenate_496 (Concatenate)   (None, 2)            0           lambda_90[0][0]
#                                                                  lambda_91[0][0]
# __________________________________________________________________________________________________
# lambda_92 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_93 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_94 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_95 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# dense_722 (Dense)               (None, 1)            3           concatenate_719[0][0]
# __________________________________________________________________________________________________
# lambda_127 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# minimum_171 (Minimum)           (None, 1)            0           lambda_120[0][0]
#                                                                  lambda_121[0][0]
# __________________________________________________________________________________________________
# lambda_122 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# dense_798 (Dense)               (None, 1)            3           concatenate_791[0][0]
# __________________________________________________________________________________________________
# lambda_132 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_2 (TFOpLambda)  (None, 1)            0           tf.math.minimum_1[0][0]
#                                                                  dense_27[0][0]
# __________________________________________________________________________________________________
# dense_35 (Dense)                (None, 1)            3           concatenate_32[0][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 2)            0           lambda_10[0][0]
#                                                                  lambda_11[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_13 (TFOpLambda) (None, 1)            0           tf.math.minimum_12[0][0]
#                                                                  minimum_54[0][0]
# __________________________________________________________________________________________________
# minimum_60 (Minimum)            (None, 1)            0           dense_227[0][0]
#                                                                  dense_235[0][0]
# __________________________________________________________________________________________________
# dense_251 (Dense)               (None, 1)            3           concatenate_248[0][0]
# __________________________________________________________________________________________________
# dense_259 (Dense)               (None, 1)            3           concatenate_256[0][0]
# __________________________________________________________________________________________________
# concatenate_272 (Concatenate)   (None, 2)            0           lambda_52[0][0]
#                                                                  lambda_53[0][0]
# __________________________________________________________________________________________________
# concatenate_280 (Concatenate)   (None, 2)            0           lambda_54[0][0]
#                                                                  lambda_55[0][0]
# __________________________________________________________________________________________________
# lambda_56 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_57 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_58 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_59 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# minimum_114 (Minimum)           (None, 1)            0           dense_443[0][0]
#                                                                  dense_451[0][0]
# __________________________________________________________________________________________________
# minimum_120 (Minimum)           (None, 1)            0           dense_467[0][0]
#                                                                  dense_475[0][0]
# __________________________________________________________________________________________________
# dense_491 (Dense)               (None, 1)            3           concatenate_488[0][0]
# __________________________________________________________________________________________________
# dense_499 (Dense)               (None, 1)            3           concatenate_496[0][0]
# __________________________________________________________________________________________________
# concatenate_512 (Concatenate)   (None, 2)            0           lambda_92[0][0]
#                                                                  lambda_93[0][0]
# __________________________________________________________________________________________________
# concatenate_520 (Concatenate)   (None, 2)            0           lambda_94[0][0]
#                                                                  lambda_95[0][0]
# __________________________________________________________________________________________________
# lambda_96 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_97 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_98 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_99 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# concatenate_727 (Concatenate)   (None, 2)            0           dense_722[0][0]
#                                                                  lambda_127[0][0]
# __________________________________________________________________________________________________
# minimum_173 (Minimum)           (None, 1)            0           minimum_171[0][0]
#                                                                  lambda_122[0][0]
# __________________________________________________________________________________________________
# lambda_123 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# concatenate_799 (Concatenate)   (None, 2)            0           dense_798[0][0]
#                                                                  lambda_132[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_3 (TFOpLambda)  (None, 1)            0           tf.math.minimum_2[0][0]
#                                                                  dense_35[0][0]
# __________________________________________________________________________________________________
# dense_43 (Dense)                (None, 1)            3           concatenate_40[0][0]
# __________________________________________________________________________________________________
# concatenate_48 (Concatenate)    (None, 2)            0           lambda_12[0][0]
#                                                                  lambda_13[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_14 (TFOpLambda) (None, 1)            0           tf.math.minimum_13[0][0]
#                                                                  minimum_60[0][0]
# __________________________________________________________________________________________________
# minimum_66 (Minimum)            (None, 1)            0           dense_251[0][0]
#                                                                  dense_259[0][0]
# __________________________________________________________________________________________________
# dense_275 (Dense)               (None, 1)            3           concatenate_272[0][0]
# __________________________________________________________________________________________________
# dense_283 (Dense)               (None, 1)            3           concatenate_280[0][0]
# __________________________________________________________________________________________________
# concatenate_296 (Concatenate)   (None, 2)            0           lambda_56[0][0]
#                                                                  lambda_57[0][0]
# __________________________________________________________________________________________________
# concatenate_304 (Concatenate)   (None, 2)            0           lambda_58[0][0]
#                                                                  lambda_59[0][0]
# __________________________________________________________________________________________________
# lambda_60 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_61 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_62 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_63 (Lambda)              (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_23 (TFOpLambda) (None, 1)            0           minimum_114[0][0]
#                                                                  minimum_120[0][0]
# __________________________________________________________________________________________________
# minimum_126 (Minimum)           (None, 1)            0           dense_491[0][0]
#                                                                  dense_499[0][0]
# __________________________________________________________________________________________________
# dense_515 (Dense)               (None, 1)            3           concatenate_512[0][0]
# __________________________________________________________________________________________________
# dense_523 (Dense)               (None, 1)            3           concatenate_520[0][0]
# __________________________________________________________________________________________________
# concatenate_536 (Concatenate)   (None, 2)            0           lambda_96[0][0]
#                                                                  lambda_97[0][0]
# __________________________________________________________________________________________________
# concatenate_544 (Concatenate)   (None, 2)            0           lambda_98[0][0]
#                                                                  lambda_99[0][0]
# __________________________________________________________________________________________________
# lambda_100 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_101 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_102 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_103 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# dense_730 (Dense)               (None, 1)            3           concatenate_727[0][0]
# __________________________________________________________________________________________________
# lambda_128 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# minimum_175 (Minimum)           (None, 1)            0           minimum_173[0][0]
#                                                                  lambda_123[0][0]
# __________________________________________________________________________________________________
# lambda_124 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# dense_806 (Dense)               (None, 1)            3           concatenate_799[0][0]
# __________________________________________________________________________________________________
# lambda_133 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_143 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_144 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_145 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_146 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_149 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_150 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_151 (Lambda)             (None, 1)            0           Input[0][0]
# __________________________________________________________________________________________________
# lambda_152 (Lambda)             (None, 1)            0           Input[0][0]
# ...
# __________________________________________________________________________________________________
# dense_889 (Dense)               (None, 1)            3           concatenate_880[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_32 (TFOpLambda) (None, 1)            0           minimum_232[0][0]
#                                                                  minimum_242[0][0]
# __________________________________________________________________________________________________
# minimum_252 (Minimum)           (None, 1)            0           minimum_248[0][0]
#                                                                  dense_1009[0][0]
# __________________________________________________________________________________________________
# minimum_258 (Minimum)           (None, 1)            0           dense_1025[0][0]
#                                                                  dense_1033[0][0]
# __________________________________________________________________________________________________
# dense_1049 (Dense)              (None, 1)            3           concatenate_1040[0][0]
# __________________________________________________________________________________________________
# dense_1065 (Dense)              (None, 1)            3           concatenate_1056[0][0]
# __________________________________________________________________________________________________
# dense_1073 (Dense)              (None, 1)            3           concatenate_1064[0][0]
# __________________________________________________________________________________________________
# concatenate_1080 (Concatenate)  (None, 2)            0           lambda_171[0][0]
#                                                                  lambda_172[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_20 (TFOpLambda) (None, 1)            0           tf.math.minimum_19[0][0]
#                                                                  minimum_96[0][0]
# __________________________________________________________________________________________________
# minimum_102 (Minimum)           (None, 1)            0           dense_395[0][0]
#                                                                  dense_403[0][0]
# __________________________________________________________________________________________________
# dense_419 (Dense)               (None, 1)            3           concatenate_416[0][0]
# __________________________________________________________________________________________________
# dense_427 (Dense)               (None, 1)            3           concatenate_424[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_29 (TFOpLambda) (None, 1)            0           tf.math.minimum_28[0][0]
#                                                                  minimum_156[0][0]
# __________________________________________________________________________________________________
# minimum_162 (Minimum)           (None, 1)            0           dense_635[0][0]
#                                                                  dense_643[0][0]
# __________________________________________________________________________________________________
# dense_659 (Dense)               (None, 1)            3           concatenate_656[0][0]
# __________________________________________________________________________________________________
# dense_667 (Dense)               (None, 1)            3           concatenate_664[0][0]
# __________________________________________________________________________________________________
# dense_765 (Dense)               (None, 1)            3           concatenate_760[0][0]
# __________________________________________________________________________________________________
# dense_773 (Dense)               (None, 1)            2           tf.math.minimum_8[0][0]
# __________________________________________________________________________________________________
# dense_783 (Dense)               (None, 1)            3           concatenate_776[0][0]
# __________________________________________________________________________________________________
# dense_824 (Dense)               (None, 1)            3           concatenate_816[0][0]
# __________________________________________________________________________________________________
# minimum_222 (Minimum)           (None, 1)            0           minimum_218[0][0]
#                                                                  dense_889[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_33 (TFOpLambda) (None, 1)            0           tf.math.minimum_32[0][0]
#                                                                  minimum_252[0][0]
# __________________________________________________________________________________________________
# minimum_262 (Minimum)           (None, 1)            0           minimum_258[0][0]
#                                                                  dense_1049[0][0]
# __________________________________________________________________________________________________
# minimum_268 (Minimum)           (None, 1)            0           dense_1065[0][0]
#                                                                  dense_1073[0][0]
# __________________________________________________________________________________________________
# dense_1089 (Dense)              (None, 1)            3           concatenate_1080[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_21 (TFOpLambda) (None, 1)            0           tf.math.minimum_20[0][0]
#                                                                  minimum_102[0][0]
# __________________________________________________________________________________________________
# minimum_108 (Minimum)           (None, 1)            0           dense_419[0][0]
#                                                                  dense_427[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_30 (TFOpLambda) (None, 1)            0           tf.math.minimum_29[0][0]
#                                                                  minimum_162[0][0]
# __________________________________________________________________________________________________
# minimum_168 (Minimum)           (None, 1)            0           dense_659[0][0]
#                                                                  dense_667[0][0]
# __________________________________________________________________________________________________
# minimum_192 (Minimum)           (None, 1)            0           dense_765[0][0]
#                                                                  dense_773[0][0]
# __________________________________________________________________________________________________
# minimum_206 (Minimum)           (None, 1)            0           dense_783[0][0]
#                                                                  dense_824[0][0]
# __________________________________________________________________________________________________
# dense_840 (Dense)               (None, 1)            2           tf.math.minimum_8[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_34 (TFOpLambda) (None, 1)            0           tf.math.minimum_33[0][0]
#                                                                  minimum_262[0][0]
# __________________________________________________________________________________________________
# minimum_272 (Minimum)           (None, 1)            0           minimum_268[0][0]
#                                                                  dense_1089[0][0]
# __________________________________________________________________________________________________
# dense_1146 (Dense)              (None, 1)            2           tf.math.minimum_8[0][0]
# __________________________________________________________________________________________________
# dense_1147 (Dense)              (None, 1)            2           minimum_222[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_22 (TFOpLambda) (None, 1)            0           tf.math.minimum_21[0][0]
#                                                                  minimum_108[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_31 (TFOpLambda) (None, 1)            0           tf.math.minimum_30[0][0]
#                                                                  minimum_168[0][0]
# __________________________________________________________________________________________________
# minimum_208 (Minimum)           (None, 1)            0           minimum_206[0][0]
#                                                                  dense_840[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_35 (TFOpLambda) (None, 1)            0           tf.math.minimum_34[0][0]
#                                                                  minimum_272[0][0]
# __________________________________________________________________________________________________
# minimum_284 (Minimum)           (None, 1)            0           dense_1146[0][0]
#                                                                  dense_1147[0][0]
# __________________________________________________________________________________________________
# dense_1156 (Dense)              (None, 1)            2           minimum_192[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           704         Input[0][0]
# __________________________________________________________________________________________________
# minimum_274 (Minimum)           (None, 1)            0           tf.math.minimum_31[0][0]
#                                                                  tf.math.minimum_22[0][0]
# __________________________________________________________________________________________________
# dense_1113 (Dense)              (None, 1)            2           tf.math.minimum_35[0][0]
# __________________________________________________________________________________________________
# minimum_278 (Minimum)           (None, 1)            0           minimum_192[0][0]
#                                                                  minimum_222[0][0]
# __________________________________________________________________________________________________
# minimum_280 (Minimum)           (None, 1)            0           minimum_208[0][0]
#                                                                  minimum_222[0][0]
# __________________________________________________________________________________________________
# minimum_286 (Minimum)           (None, 1)            0           minimum_284[0][0]
#                                                                  dense_1156[0][0]
# __________________________________________________________________________________________________
# dense_1165 (Dense)              (None, 1)            2           minimum_208[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           4160        dense[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_36 (TFOpLambda) (None, 1)            0           minimum_192[0][0]
#                                                                  minimum_208[0][0]
# __________________________________________________________________________________________________
# minimum_276 (Minimum)           (None, 1)            0           minimum_274[0][0]
#                                                                  dense_1113[0][0]
# __________________________________________________________________________________________________
# tf.math.minimum_38 (TFOpLambda) (None, 1)            0           minimum_278[0][0]
#                                                                  minimum_280[0][0]
# __________________________________________________________________________________________________
# minimum_282 (Minimum)           (None, 1)            0           minimum_208[0][0]
#                                                                  minimum_222[0][0]
# __________________________________________________________________________________________________
# minimum_288 (Minimum)           (None, 1)            0           minimum_286[0][0]
#                                                                  dense_1165[0][0]
# __________________________________________________________________________________________________
# concatenate_1160 (Concatenate)  (None, 74)           0           dense_1[0][0]
#                                                                  tf.math.minimum_8[0][0]
#                                                                  tf.math.minimum_22[0][0]
#                                                                  tf.math.minimum_31[0][0]
#                                                                  tf.math.minimum_36[0][0]
#                                                                  minimum_222[0][0]
#                                                                  minimum_276[0][0]
#                                                                  tf.math.minimum_35[0][0]
#                                                                  tf.math.minimum_38[0][0]
#                                                                  minimum_282[0][0]
#                                                                  minimum_288[0][0]
# __________________________________________________________________________________________________
# dense_1174 (Dense)              (None, 10)           750         concatenate_1160[0][0]
# ==================================================================================================
# Total params: 5,945
# Trainable params: 5,614
# Non-trainable params: 331
# __________________________________________________________________________________________________

# %% [markdown]
# Training.

# %%
injector.predictor.fit(train_x, train_y, verbose=1, batch_size=32, epochs=100)
# Out:
# 2022-03-08 15:43:55.508074: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-03-08 15:43:55.508242: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 1/100
# 782/782 [==============================] - 3s 1ms/step - loss: 1.0029 - accuracy: 0.5090
# Epoch 2/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.9579 - accuracy: 0.5381
# Epoch 3/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.9447 - accuracy: 0.5451
# Epoch 4/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.9347 - accuracy: 0.5534
# Epoch 5/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.9249 - accuracy: 0.5547
# Epoch 6/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.9153 - accuracy: 0.5625
# Epoch 7/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.9071 - accuracy: 0.5667
# Epoch 8/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.9000 - accuracy: 0.5699
# Epoch 9/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.8921 - accuracy: 0.5762
# Epoch 10/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.8852 - accuracy: 0.5822
# Epoch 11/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.8785 - accuracy: 0.5856
# Epoch 12/100
# 782/782 [==============================] - 1s 2ms/step - loss: 0.8725 - accuracy: 0.5882
# Epoch 13/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.8664 - accuracy: 0.5904
# Epoch 14/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.8589 - accuracy: 0.5989
# Epoch 15/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.8505 - accuracy: 0.6071
# Epoch 16/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.8428 - accuracy: 0.6094
# Epoch 17/100
# 782/782 [==============================] - 1s 2ms/step - loss: 0.8340 - accuracy: 0.6143
# Epoch 18/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.8242 - accuracy: 0.6228
# Epoch 19/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.8139 - accuracy: 0.6286
# Epoch 20/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.8004 - accuracy: 0.6342
# Epoch 21/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.7927 - accuracy: 0.6417
# Epoch 22/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.7758 - accuracy: 0.6506
# Epoch 23/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.7654 - accuracy: 0.6552
# Epoch 24/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.7534 - accuracy: 0.6618
# Epoch 25/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.7379 - accuracy: 0.6707
# Epoch 26/100
# 782/782 [==============================] - 1s 2ms/step - loss: 0.7257 - accuracy: 0.6789
# Epoch 27/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.7067 - accuracy: 0.6911
# Epoch 28/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.6916 - accuracy: 0.7014
# Epoch 29/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.6736 - accuracy: 0.7131
# Epoch 30/100
# 782/782 [==============================] - 1s 2ms/step - loss: 0.6555 - accuracy: 0.7214
# Epoch 31/100
# 782/782 [==============================] - 1s 2ms/step - loss: 0.6361 - accuracy: 0.7317
# Epoch 32/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.6162 - accuracy: 0.7443
# Epoch 33/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.5972 - accuracy: 0.7547
# Epoch 34/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.5774 - accuracy: 0.7640
# Epoch 35/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.5601 - accuracy: 0.7749
# Epoch 36/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.5379 - accuracy: 0.7856
# Epoch 37/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.5173 - accuracy: 0.7989
# Epoch 38/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.5021 - accuracy: 0.8044
# Epoch 39/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.4864 - accuracy: 0.8093
# Epoch 40/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.4682 - accuracy: 0.8216
# Epoch 41/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.4524 - accuracy: 0.8261
# Epoch 42/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.4405 - accuracy: 0.8332
# Epoch 43/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.4218 - accuracy: 0.8415
# Epoch 44/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.4116 - accuracy: 0.8429
# Epoch 45/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.3993 - accuracy: 0.8481
# Epoch 46/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.3899 - accuracy: 0.8527
# Epoch 47/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.3756 - accuracy: 0.8581
# Epoch 48/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.3671 - accuracy: 0.8638
# Epoch 49/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.3542 - accuracy: 0.8660
# Epoch 50/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.3401 - accuracy: 0.8731
# Epoch 51/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.3305 - accuracy: 0.8788
# Epoch 52/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.3169 - accuracy: 0.8820
# Epoch 53/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.3081 - accuracy: 0.8870
# Epoch 54/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.2952 - accuracy: 0.8917
# Epoch 55/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.2822 - accuracy: 0.8967
# Epoch 56/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.2662 - accuracy: 0.9034
# Epoch 57/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.2587 - accuracy: 0.9077
# Epoch 58/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.2419 - accuracy: 0.9132
# Epoch 59/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.2355 - accuracy: 0.9158
# Epoch 60/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.2210 - accuracy: 0.9228
# Epoch 61/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.2123 - accuracy: 0.9265
# Epoch 62/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.1955 - accuracy: 0.9353
# Epoch 63/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.1887 - accuracy: 0.9349
# Epoch 64/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.1786 - accuracy: 0.9419
# Epoch 65/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.1722 - accuracy: 0.9430
# Epoch 66/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.1613 - accuracy: 0.9473
# Epoch 67/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.1517 - accuracy: 0.9511
# Epoch 68/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.1437 - accuracy: 0.9557
# Epoch 69/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.1403 - accuracy: 0.9541
# Epoch 70/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.1279 - accuracy: 0.9613
# Epoch 71/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.1274 - accuracy: 0.9614
# Epoch 72/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.1183 - accuracy: 0.9649
# Epoch 73/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.1114 - accuracy: 0.9673
# Epoch 74/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.1100 - accuracy: 0.9675
# Epoch 75/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.1036 - accuracy: 0.9687
# Epoch 76/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.1034 - accuracy: 0.9701
# Epoch 77/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.0903 - accuracy: 0.9752
# Epoch 78/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.0875 - accuracy: 0.9761
# Epoch 79/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.0863 - accuracy: 0.9766
# Epoch 80/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.0809 - accuracy: 0.9772
# Epoch 81/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.0864 - accuracy: 0.9749
# Epoch 82/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.0741 - accuracy: 0.9796
# Epoch 83/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.0684 - accuracy: 0.9824
# Epoch 84/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.0757 - accuracy: 0.9795
# Epoch 85/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.0658 - accuracy: 0.9836
# Epoch 86/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.0600 - accuracy: 0.9851
# Epoch 87/100
# 782/782 [==============================] - 1s 2ms/step - loss: 0.0602 - accuracy: 0.9840
# Epoch 88/100
# 782/782 [==============================] - 1s 2ms/step - loss: 0.0654 - accuracy: 0.9822
# Epoch 89/100
# 782/782 [==============================] - 1s 2ms/step - loss: 0.0576 - accuracy: 0.9851
# Epoch 90/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.0599 - accuracy: 0.9838
# Epoch 91/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.0442 - accuracy: 0.9901
# Epoch 92/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.0571 - accuracy: 0.9858
# Epoch 93/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.0512 - accuracy: 0.9874
# Epoch 94/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.0468 - accuracy: 0.9889
# Epoch 95/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.0432 - accuracy: 0.9905
# Epoch 96/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.0443 - accuracy: 0.9895
# Epoch 97/100
# 782/782 [==============================] - 1s 2ms/step - loss: 0.0474 - accuracy: 0.9882
# Epoch 98/100
# 782/782 [==============================] - 1s 2ms/step - loss: 0.0369 - accuracy: 0.9924
# Epoch 99/100
# 782/782 [==============================] - 1s 2ms/step - loss: 0.0368 - accuracy: 0.9919
# Epoch 100/100
# 782/782 [==============================] - 1s 1ms/step - loss: 0.0399 - accuracy: 0.9898

# %% [markdown]
# Removing the injected rules from the network.

# %% [markdown]
# Evaluation.

# %%
injector.predictor.evaluate(test_x, test_y)
# Out:
# 31250/31250 [==============================] - 36s 1ms/step - loss: 0.0660 - accuracy: 0.9862
# [0.06597686558961868, 0.9862030148506165]

# %%
accuracies, weights = get_class_accuracy(injector.predictor, test_x, test_y)
accuracies
# Out:
# [0.9975798519180621,
#  0.9960354841916411,
#  0.8672672294317753,
#  0.899578618436627,
#  0.824967824967825,
#  0.7980961923847696,
#  0.19452247191011235,
#  0.030434782608695653,
#  0.08333333333333333,
#  0.0]

# %%
get_f1(injector.predictor, test_x, test_y)
# Out:
# 0.581154504407779

# %% [markdown]
# ### The same network without knowledge injection

# %%
set_random_seed(0)
input_features = Input((10,), name='Input')
network = get_mlp(input_layer=input_features, output=10, layers=3, neurons=64, activation_function='relu', last_activation_function='softmax')
model = Model(input_features, network)
model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 10)]              0
# _________________________________________________________________
# dense_1175 (Dense)           (None, 64)                704
# _________________________________________________________________
# dense_1176 (Dense)           (None, 64)                4160
# _________________________________________________________________
# dense_1177 (Dense)           (None, 10)                650
# =================================================================
# Total params: 5,514
# Trainable params: 5,514
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_x, train_y, verbose=1, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 782/782 [==============================] - 0s 395us/step - loss: 1.0413 - accuracy: 0.4912
# Epoch 2/100
# 782/782 [==============================] - 0s 400us/step - loss: 0.9710 - accuracy: 0.5263
# Epoch 3/100
# 782/782 [==============================] - 0s 394us/step - loss: 0.9570 - accuracy: 0.5398
# Epoch 4/100
# 782/782 [==============================] - 0s 398us/step - loss: 0.9496 - accuracy: 0.5455
# Epoch 5/100
# 782/782 [==============================] - 0s 404us/step - loss: 0.9406 - accuracy: 0.5541
# Epoch 6/100
# 782/782 [==============================] - 0s 408us/step - loss: 0.9340 - accuracy: 0.5612
# Epoch 7/100
# 782/782 [==============================] - 0s 397us/step - loss: 0.9261 - accuracy: 0.5595
# Epoch 8/100
# 782/782 [==============================] - 0s 395us/step - loss: 0.9191 - accuracy: 0.5701
# Epoch 9/100
# 782/782 [==============================] - 0s 394us/step - loss: 0.9123 - accuracy: 0.5746
# Epoch 10/100
# 782/782 [==============================] - 0s 394us/step - loss: 0.9036 - accuracy: 0.5827
# Epoch 11/100
# 782/782 [==============================] - 0s 404us/step - loss: 0.8939 - accuracy: 0.5859
# Epoch 12/100
# 782/782 [==============================] - 0s 393us/step - loss: 0.8838 - accuracy: 0.5943
# Epoch 13/100
# 782/782 [==============================] - 0s 400us/step - loss: 0.8764 - accuracy: 0.6021
# Epoch 14/100
# 782/782 [==============================] - 0s 395us/step - loss: 0.8633 - accuracy: 0.6153
# Epoch 15/100
# 782/782 [==============================] - 0s 395us/step - loss: 0.8494 - accuracy: 0.6191
# Epoch 16/100
# 782/782 [==============================] - 0s 395us/step - loss: 0.8352 - accuracy: 0.6321
# Epoch 17/100
# 782/782 [==============================] - 0s 394us/step - loss: 0.8234 - accuracy: 0.6411
# Epoch 18/100
# 782/782 [==============================] - 0s 395us/step - loss: 0.8090 - accuracy: 0.6468
# Epoch 19/100
# 782/782 [==============================] - 0s 435us/step - loss: 0.7961 - accuracy: 0.6568
# Epoch 20/100
# 782/782 [==============================] - 0s 447us/step - loss: 0.7793 - accuracy: 0.6644
# Epoch 21/100
# 782/782 [==============================] - 0s 434us/step - loss: 0.7648 - accuracy: 0.6726
# Epoch 22/100
# 782/782 [==============================] - 0s 448us/step - loss: 0.7462 - accuracy: 0.6818
# Epoch 23/100
# 782/782 [==============================] - 0s 448us/step - loss: 0.7342 - accuracy: 0.6878
# Epoch 24/100
# 782/782 [==============================] - 0s 440us/step - loss: 0.7179 - accuracy: 0.6941
# Epoch 25/100
# 782/782 [==============================] - 0s 404us/step - loss: 0.7015 - accuracy: 0.6993
# Epoch 26/100
# 782/782 [==============================] - 0s 395us/step - loss: 0.6889 - accuracy: 0.7110
# Epoch 27/100
# 782/782 [==============================] - 0s 392us/step - loss: 0.6710 - accuracy: 0.7203
# Epoch 28/100
# 782/782 [==============================] - 0s 400us/step - loss: 0.6553 - accuracy: 0.7281
# Epoch 29/100
# 782/782 [==============================] - 0s 392us/step - loss: 0.6402 - accuracy: 0.7330
# Epoch 30/100
# 782/782 [==============================] - 0s 394us/step - loss: 0.6244 - accuracy: 0.7435
# Epoch 31/100
# 782/782 [==============================] - 0s 390us/step - loss: 0.6091 - accuracy: 0.7514
# Epoch 32/100
# 782/782 [==============================] - 0s 397us/step - loss: 0.5924 - accuracy: 0.7599
# Epoch 33/100
# 782/782 [==============================] - 0s 404us/step - loss: 0.5766 - accuracy: 0.7645
# Epoch 34/100
# 782/782 [==============================] - 0s 392us/step - loss: 0.5634 - accuracy: 0.7738
# Epoch 35/100
# 782/782 [==============================] - 0s 398us/step - loss: 0.5414 - accuracy: 0.7854
# Epoch 36/100
# 782/782 [==============================] - 0s 398us/step - loss: 0.5234 - accuracy: 0.7924
# Epoch 37/100
# 782/782 [==============================] - 0s 395us/step - loss: 0.5030 - accuracy: 0.8011
# Epoch 38/100
# 782/782 [==============================] - 0s 382us/step - loss: 0.4930 - accuracy: 0.8089
# Epoch 39/100
# 782/782 [==============================] - 0s 427us/step - loss: 0.4750 - accuracy: 0.8159
# Epoch 40/100
# 782/782 [==============================] - 0s 426us/step - loss: 0.4554 - accuracy: 0.8272
# Epoch 41/100
# 782/782 [==============================] - 0s 401us/step - loss: 0.4353 - accuracy: 0.8359
# Epoch 42/100
# 782/782 [==============================] - 0s 396us/step - loss: 0.4226 - accuracy: 0.8434
# Epoch 43/100
# 782/782 [==============================] - 0s 399us/step - loss: 0.4029 - accuracy: 0.8507
# Epoch 44/100
# 782/782 [==============================] - 0s 396us/step - loss: 0.3834 - accuracy: 0.8620
# Epoch 45/100
# 782/782 [==============================] - 0s 404us/step - loss: 0.3650 - accuracy: 0.8700
# Epoch 46/100
# 782/782 [==============================] - 0s 446us/step - loss: 0.3514 - accuracy: 0.8771
# Epoch 47/100
# 782/782 [==============================] - 0s 451us/step - loss: 0.3316 - accuracy: 0.8843
# Epoch 48/100
# 782/782 [==============================] - 0s 442us/step - loss: 0.3187 - accuracy: 0.8891
# Epoch 49/100
# 782/782 [==============================] - 0s 447us/step - loss: 0.3072 - accuracy: 0.8958
# Epoch 50/100
# 782/782 [==============================] - 0s 420us/step - loss: 0.2892 - accuracy: 0.9043
# Epoch 51/100
# 782/782 [==============================] - 0s 394us/step - loss: 0.2762 - accuracy: 0.9077
# Epoch 52/100
# 782/782 [==============================] - 0s 399us/step - loss: 0.2708 - accuracy: 0.9111
# Epoch 53/100
# 782/782 [==============================] - 0s 398us/step - loss: 0.2445 - accuracy: 0.9238
# Epoch 54/100
# 782/782 [==============================] - 0s 395us/step - loss: 0.2448 - accuracy: 0.9197
# Epoch 55/100
# 782/782 [==============================] - 0s 396us/step - loss: 0.2260 - accuracy: 0.9288
# Epoch 56/100
# 782/782 [==============================] - 0s 375us/step - loss: 0.2109 - accuracy: 0.9351
# Epoch 57/100
# 782/782 [==============================] - 0s 389us/step - loss: 0.2027 - accuracy: 0.9377
# Epoch 58/100
# 782/782 [==============================] - 0s 396us/step - loss: 0.1863 - accuracy: 0.9457
# Epoch 59/100
# 782/782 [==============================] - 0s 396us/step - loss: 0.1744 - accuracy: 0.9508
# Epoch 60/100
# 782/782 [==============================] - 0s 397us/step - loss: 0.1660 - accuracy: 0.9541
# Epoch 61/100
# 782/782 [==============================] - 0s 398us/step - loss: 0.1575 - accuracy: 0.9559
# Epoch 62/100
# 782/782 [==============================] - 0s 397us/step - loss: 0.1557 - accuracy: 0.9565
# Epoch 63/100
# 782/782 [==============================] - 0s 397us/step - loss: 0.1358 - accuracy: 0.9649
# Epoch 64/100
# 782/782 [==============================] - 0s 393us/step - loss: 0.1324 - accuracy: 0.9669
# Epoch 65/100
# 782/782 [==============================] - 0s 402us/step - loss: 0.1343 - accuracy: 0.9628
# Epoch 66/100
# 782/782 [==============================] - 0s 398us/step - loss: 0.1247 - accuracy: 0.9678
# Epoch 67/100
# 782/782 [==============================] - 0s 394us/step - loss: 0.1182 - accuracy: 0.9697
# Epoch 68/100
# 782/782 [==============================] - 0s 403us/step - loss: 0.1113 - accuracy: 0.9728
# Epoch 69/100
# 782/782 [==============================] - 0s 428us/step - loss: 0.1116 - accuracy: 0.9707
# Epoch 70/100
# 782/782 [==============================] - 0s 416us/step - loss: 0.1038 - accuracy: 0.9754
# Epoch 71/100
# 782/782 [==============================] - 0s 408us/step - loss: 0.1003 - accuracy: 0.9762
# Epoch 72/100
# 782/782 [==============================] - 0s 407us/step - loss: 0.1002 - accuracy: 0.9747
# Epoch 73/100
# 782/782 [==============================] - 0s 409us/step - loss: 0.0925 - accuracy: 0.9782
# Epoch 74/100
# 782/782 [==============================] - 0s 400us/step - loss: 0.0953 - accuracy: 0.9764
# Epoch 75/100
# 782/782 [==============================] - 0s 409us/step - loss: 0.0841 - accuracy: 0.9803
# Epoch 76/100
# 782/782 [==============================] - 0s 424us/step - loss: 0.0930 - accuracy: 0.9758
# Epoch 77/100
# 782/782 [==============================] - 0s 419us/step - loss: 0.0775 - accuracy: 0.9825
# Epoch 78/100
# 782/782 [==============================] - 0s 412us/step - loss: 0.0915 - accuracy: 0.9765
# Epoch 79/100
# 782/782 [==============================] - 0s 557us/step - loss: 0.0740 - accuracy: 0.9832
# Epoch 80/100
# 782/782 [==============================] - 0s 430us/step - loss: 0.0793 - accuracy: 0.9804
# Epoch 81/100
# 782/782 [==============================] - 0s 403us/step - loss: 0.0682 - accuracy: 0.9846
# Epoch 82/100
# 782/782 [==============================] - 0s 439us/step - loss: 0.0747 - accuracy: 0.9814
# Epoch 83/100
# 782/782 [==============================] - 0s 446us/step - loss: 0.0725 - accuracy: 0.9832
# Epoch 84/100
# 782/782 [==============================] - 0s 433us/step - loss: 0.0671 - accuracy: 0.9839
# Epoch 85/100
# 782/782 [==============================] - 0s 421us/step - loss: 0.0701 - accuracy: 0.9834
# Epoch 86/100
# 782/782 [==============================] - 0s 410us/step - loss: 0.0591 - accuracy: 0.9873
# Epoch 87/100
# 782/782 [==============================] - 0s 425us/step - loss: 0.0649 - accuracy: 0.9848
# Epoch 88/100
# 782/782 [==============================] - 0s 459us/step - loss: 0.0631 - accuracy: 0.9850
# Epoch 89/100
# 782/782 [==============================] - 0s 432us/step - loss: 0.0625 - accuracy: 0.9852
# Epoch 90/100
# 782/782 [==============================] - 0s 434us/step - loss: 0.0619 - accuracy: 0.9836
# Epoch 91/100
# 782/782 [==============================] - 0s 425us/step - loss: 0.0647 - accuracy: 0.9844
# Epoch 92/100
# 782/782 [==============================] - 0s 409us/step - loss: 0.0488 - accuracy: 0.9892
# Epoch 93/100
# 782/782 [==============================] - 0s 437us/step - loss: 0.0570 - accuracy: 0.9871
# Epoch 94/100
# 782/782 [==============================] - 0s 410us/step - loss: 0.0688 - accuracy: 0.9833
# Epoch 95/100
# 782/782 [==============================] - 0s 420us/step - loss: 0.0477 - accuracy: 0.9896
# Epoch 96/100
# 782/782 [==============================] - 0s 435us/step - loss: 0.0601 - accuracy: 0.9843
# Epoch 97/100
# 782/782 [==============================] - 0s 431us/step - loss: 0.0473 - accuracy: 0.9897
# Epoch 98/100
# 782/782 [==============================] - 0s 428us/step - loss: 0.0535 - accuracy: 0.9865
# Epoch 99/100
# 782/782 [==============================] - 0s 417us/step - loss: 0.0481 - accuracy: 0.9892
# Epoch 100/100
# 782/782 [==============================] - 0s 416us/step - loss: 0.0454 - accuracy: 0.9897

# %%
model.evaluate(test_x, test_y)
# Out:
# 31250/31250 [==============================] - 7s 219us/step - loss: 0.1261 - accuracy: 0.9664
# [0.1261490285396576, 0.9664030075073242]

# %%
accuracies, weights = get_class_accuracy(model, test_x, test_y)
accuracies
# Out:
# [0.9944434357723025,
#  0.966158419684827,
#  0.8478224350090294,
#  0.871028833862033,
#  0.15933075933075933,
#  0.011523046092184368,
#  0.2478932584269663,
#  0.05217391304347826,
#  0.0,
#  0.0]

# %%
get_f1(model, test_x, test_y)
# Out:
# 0.4355657347081636
